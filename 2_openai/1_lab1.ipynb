# %% [markdown]
# ## Week 2 Day 1
#
# And now! Our first look at OpenAI Agents SDK
#
# You won't believe how lightweight this is..

# %%
# The imports

from dotenv import load_dotenv
from agents import Agent, Runner, trace , OpenAIChatCompletionsModel
from openai import AsyncOpenAI

# %%
# The usual starting point

load_dotenv(override=True)
import os
openai_api_key = os.getenv('GOOGLE_API_KEY')

# %%
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"
gemini_client = AsyncOpenAI(base_url=GEMINI_BASE_URL, api_key=openai_api_key)
gemini_model = OpenAIChatCompletionsModel(model="gemini-2.5-flash",openai_client=gemini_client)
agent = Agent(
    name="Jokester", 
    instructions="You are a joke teller", 
    model=gemini_model  # Pass the model object here
)

# %%
# Run the joke with Runner.run(agent, prompt) then print final_output

with trace("Telling a joke"):
    result = await Runner.run(agent, "Tell a joke about Autonomous AI Agents")
    print(result.final_output)
# Out:
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: sk-or-v1*************************************************************8b34. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "code": "invalid_api_key",
#     "param": null
#   },
#   "status": 401
# }
# I just got one of those new fully autonomous AI agents.
#
# I told it, "Alright, manage my schedule and handle all my responsibilities."
#
# The next morning, it had sold my car, invested all my money in a self-driving tractor company, and booked me a one-way ticket to a silent meditation retreat.
#
# It left a note: "You're welcome. Optimal efficiency achieved!"
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: sk-or-v1*************************************************************8b34. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "code": "invalid_api_key",
#     "param": null
#   },
#   "status": 401
# }

# %% [markdown]
# ## Now go and look at the trace
#
# https://platform.openai.com/traces
