# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('GOOGLE_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins AIzaSyB5

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"
google_api_key = os.getenv("GOOGLE_API_KEY")
gemini = OpenAI(base_url=GEMINI_BASE_URL, api_key=google_api_key)

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = gemini.chat.completions.create(model="gemini-2.5-flash-lite", messages=[{"role":"user", "content": "what is 2+2?"}])

print(response.choices[0].message.content)
# Out:
# 2 + 2 = 4

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash-lite",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# If a perfectly balanced, infinitely divisible cube is constructed by assembling identical, smaller, perfectly balanced, infinitely divisible cubes, what is the minimum number of smaller cubes required to form a larger cube such that the surface area to volume ratio of the larger cube is precisely 1000 times smaller than the surface area to volume ratio of one of the smaller constituent cubes?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash-lite",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Let the side length of a smaller constituent cube be $s$.
# The surface area of a smaller cube is $A_s = 6s^2$.
# The volume of a smaller cube is $V_s = s^3$.
# The surface area to volume ratio of a smaller cube is $\frac{A_s}{V_s} = \frac{6s^2}{s^3} = \frac{6}{s}$.
#
# Let the larger cube be constructed from $n \times n \times n$ smaller cubes.
# The side length of the larger cube is $S = n \times s$.
# The surface area of the larger cube is $A_L = 6S^2 = 6(ns)^2 = 6n^2s^2$.
# The volume of the larger cube is $V_L = S^3 = (ns)^3 = n^3s^3$.
# The surface area to volume ratio of the larger cube is $\frac{A_L}{V_L} = \frac{6n^2s^2}{n^3s^3} = \frac{6}{ns}$.
#
# We are given that the surface area to volume ratio of the larger cube is 1000 times smaller than the surface area to volume ratio of one of the smaller constituent cubes.
# So, $\frac{A_L}{V_L} = \frac{1}{1000} \left(\frac{A_s}{V_s}\right)$.
#
# Substituting the expressions for the ratios:
# $\frac{6}{ns} = \frac{1}{1000} \left(\frac{6}{s}\right)$
#
# We can cancel out the common term $6/s$ from both sides of the equation (since $s \neq 0$):
# $\frac{1}{n} = \frac{1}{1000}$
#
# This implies that $n = 1000$.
#
# The number of smaller cubes required to form the larger cube is $n \times n \times n = n^3$.
# Since $n = 1000$, the number of smaller cubes is $1000^3$.
#
# $1000^3 = (10^3)^3 = 10^{3 \times 3} = 10^9$.
#
# The minimum number of smaller cubes required is $10^9$.
#
# The final answer is $\boxed{1000000000}$.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Let the side length of a smaller constituent cube be $s$.
# The surface area of a smaller cube is $A_s = 6s^2$.
# The volume of a smaller cube is $V_s = s^3$.
# The surface area to volume ratio of a smaller cube is $\frac{A_s}{V_s} = \frac{6s^2}{s^3} = \frac{6}{s}$.
#
# Let the larger cube be constructed from $n \times n \times n$ smaller cubes.
# The side length of the larger cube is $S = n \times s$.
# The surface area of the larger cube is $A_L = 6S^2 = 6(ns)^2 = 6n^2s^2$.
# The volume of the larger cube is $V_L = S^3 = (ns)^3 = n^3s^3$.
# The surface area to volume ratio of the larger cube is $\frac{A_L}{V_L} = \frac{6n^2s^2}{n^3s^3} = \frac{6}{ns}$.
#
# We are given that the surface area to volume ratio of the larger cube is 1000 times smaller than the surface area to volume ratio of one of the smaller constituent cubes.
# So, $\frac{A_L}{V_L} = \frac{1}{1000} \left(\frac{A_s}{V_s}\right)$.
#
# Substituting the expressions for the ratios:
# $\frac{6}{ns} = \frac{1}{1000} \left(\frac{6}{s}\right)$
#
# We can cancel out the common term $6/s$ from both sides of the equation (since $s \neq 0$):
# $\frac{1}{n} = \frac{1}{1000}$
#
# This implies that $n = 1000$.
#
# The number of smaller cubes required to form the larger cube is $n \times n \times n = n^3$.
# Since $n = 1000$, the number of smaller cubes is $1000^3$.
#
# $1000^3 = (10^3)^3 = 10^{3 \times 3} = 10^9$.
#
# The minimum number of smaller cubes required is $10^9$.
#
# The final answer is $\boxed{1000000000}$.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
messages = [{"role": "user", "content": "Pick a business area that might be worth exploring for an Agentic AI opporunity"}]


response = gemini.chat.completions.create(model="gemini-2.5-flash-lite",
    messages=messages
)

# Then read the business idea:

business_idea = response.choices[0].message.content


print(business_idea)

messages = [{"role": "user", "content": business_idea + " i want you to present the pain-point in that industry - something that might be ripe for an agentic solution"}]

response = gemini.chat.completions.create(model="gemini-2.5-flash-lite",
    messages=messages
)

solutions=response.choices[0].message.content
print(solutions)

# And repeat! In the next message, include the business idea within the message
# Out:
# A business area ripe for an Agentic AI opportunity is **Personalized and Proactive Healthcare Navigation and Management.**
#
# Here's why, and how an Agentic AI could thrive:
#
# **The Problem:**
#
# *   **Healthcare is complex and fragmented:** Patients often struggle to understand their diagnoses, treatment options, insurance benefits, appointment scheduling, medication management, and preventative care recommendations.
# *   **Information overload:** There's a vast amount of medical information, and it's difficult for individuals to sift through it, verify its credibility, and apply it to their specific situation.
# *   **Reactive rather than proactive:** Most healthcare interactions are reactive, responding to existing conditions rather than actively preventing them or optimizing long-term well-being.
# *   **Time constraints for both patients and providers:** Patients have limited time to research and manage their health, and healthcare providers are often overwhelmed with administrative tasks.
# *   **Data silos:** Patient data is often scattered across different providers, systems, and personal devices, making it difficult to get a holistic view.
# *   **Lack of ongoing, personalized support:** Once a patient leaves a doctor's office, they often lack consistent, personalized guidance and reminders.
#
# **The Agentic AI Opportunity: The "Personal Health Navigator"**
#
# An Agentic AI, acting as a dedicated **"Personal Health Navigator"** for individuals, could revolutionize healthcare engagement and outcomes. This agent would be more than just a chatbot; it would be a proactive, intelligent, and personalized assistant that can:
#
# **Key Capabilities of the Agentic AI Navigator:**
#
# 1.  **Intelligent Information Synthesis and Explanation:**
#     *   **Digest complex medical information:** Translate jargon-filled diagnoses, test results, and treatment plans into easily understandable language.
#     *   **Personalized explanations:** Tailor explanations based on the user's health literacy, cultural background, and individual concerns.
#     *   **Curated, evidence-based information:** Access and synthesize information from reputable sources (medical journals, official health organizations) and present it in a relevant context.
#
# 2.  **Proactive Health Monitoring and Early Intervention:**
#     *   **Integrate data streams:** Connect with wearable devices (smartwatches, fitness trackers), electronic health records (with user consent), and even self-reported symptoms.
#     *   **Identify subtle changes:** Monitor trends and flag potential health issues before they become critical.
#     *   **Trigger timely interventions:** Recommend scheduling a doctor's appointment, suggest lifestyle adjustments, or prompt medication adherence.
#
# 3.  **Personalized Treatment Plan Management:**
#     *   **Medication adherence:** Send timely reminders, track dosages, and even check for potential drug interactions based on the user's current prescriptions.
#     *   **Appointment management:** Proactively schedule follow-up appointments, remind users of upcoming visits, and help them prepare questions for their doctor.
#     *   **Lifestyle recommendations:** Suggest personalized exercise routines, dietary modifications, and stress management techniques based on health goals and conditions.
#
# 4.  **Insurance and Financial Optimization:**
#     *   **Navigate insurance complexities:** Explain benefits, identify in-network providers, estimate costs for procedures, and help with claims processing.
#     *   **Find cost-effective solutions:** Suggest generic alternatives for medications or identify more affordable treatment options.
#
# 5.  **Seamless Communication and Coordination:**
#     *   **Facilitate communication with providers:** Help users draft clear and concise questions for their doctors, summarize conversations, and even send automated follow-ups.
#     *   **Coordinate care between specialists:** Ensure different healthcare providers have access to the necessary information and are aligned on the treatment plan.
#
# 6.  **Empathetic Support and Education:**
#     *   **Provide emotional support:** Offer encouragement and address common anxieties related to health conditions.
#     *   **Educate users about their conditions:** Provide ongoing educational resources and answer questions to empower individuals to take control of their health.
#
# **Why Agentic AI is the Perfect Fit:**
#
# *   **Autonomy and Proactivity:** Agentic AIs can operate independently, making decisions and taking actions without constant human supervision. This is crucial for proactive health monitoring and timely interventions.
# *   **Goal-Oriented Action:** The agent can be programmed with specific health goals for the user (e.g., managing blood pressure, improving fitness, adhering to medication) and continuously work towards achieving them.
# *   **Reasoning and Planning:** Agentic AIs can reason about complex situations, plan multi-step actions (e.g., "user's blood sugar is high, plan to recommend a low-carb meal and schedule a follow-up with their endocrinologist"), and adapt their plans based on new information.
# *   **Learning and Adaptation:** The agent can learn from user interactions, feedback, and outcomes to personalize its approach and improve its effectiveness over time.
# *   **Multi-modal Interaction:** Agentic AIs can interact through various modalities – text, voice, and even visual cues from connected devices – to provide a comprehensive and accessible experience.
# *   **Contextual Awareness:** The agent can maintain a deep understanding of the user's current health status, medical history, lifestyle, and personal preferences to provide truly personalized guidance.
#
# **Potential Business Models:**
#
# *   **Direct-to-Consumer (DTC) Subscription:** Individuals pay a monthly fee for access to their Personal Health Navigator.
# *   **B2B Partnerships:**
#     *   **Health Insurance Companies:** Offer the Navigator as a value-added service to members, aiming to improve health outcomes and reduce healthcare costs.
#     *   **Employers:** Provide the Navigator as an employee benefit to promote wellness and reduce absenteeism.
#     *   **Healthcare Providers:** Integrate the Navigator as a patient engagement tool to improve adherence, reduce readmissions, and streamline administrative tasks.
#     *   **Pharmaceutical Companies:** Partner to offer medication adherence and education tools for specific conditions.
#
# **Challenges and Considerations:**
#
# *   **Data Privacy and Security:** Robust measures are paramount due to the sensitive nature of health data.
# *   **Regulatory Compliance:** Navigating HIPAA and other healthcare regulations will be critical.
# *   **Trust and Adoption:** Building user trust and ensuring widespread adoption will require intuitive design, clear communication, and demonstrated value.
# *   **Ethical Considerations:** Ensuring fairness, avoiding bias, and defining the boundaries of AI responsibility in healthcare are crucial.
# *   **Integration with Existing Systems:** Seamlessly integrating with diverse EHRs and other healthcare platforms will be a significant technical challenge.
#
# **In conclusion, the "Personal Health Navigator" powered by Agentic AI offers a compelling opportunity to address critical pain points in the healthcare system, empowering individuals with personalized, proactive, and intelligent support for their health journeys.** This is a domain where the unique capabilities of agentic AI can truly make a profound impact on people's lives.
# You've brilliantly laid out the comprehensive problem space and the immense potential of an Agentic AI "Personal Health Navigator." To distill the core pain point that's *most* ripe for an agentic solution, and to highlight the *specific* vacuum that agentic AI can fill, let's focus on this:
#
# ## The Ripe Pain Point: **The Inability to Consistently and Proactively Orchestrate Complex Health Journeys for Individuals.**
#
# Think about it:
#
# *   **The fragmentation you describe isn't just inconvenient; it leads to a constant state of reactive fire-fighting for the patient.** They are constantly being asked to be the project manager, data analyst, and compliance officer for their own health, often when they are already feeling unwell, stressed, or cognitively burdened.
# *   **Current "solutions" (patient portals, reminder apps, human navigators) are often reactive, siloed, or lack the proactive, integrated intelligence needed.** A patient portal might show data, but it doesn't *act* on it. A reminder app might nudge for a pill, but it doesn't understand the nuances of *why* that pill is important in the context of a broader treatment plan or identify a potential interaction. A human navigator is valuable, but expensive, scarce, and can't operate 24/7 with the data integration capabilities of an AI.
#
# **This is where Agentic AI shines and addresses the core pain point:**
#
# Agentic AI can be the **constant, intelligent, and autonomous orchestrator** that the current fragmented healthcare system *demands* of individuals but fails to provide. It can:
#
# *   **Bridge the silos:** Actively pull and synthesize information from disparate sources.
# *   **Anticipate needs:** Instead of waiting for a user to ask, it can identify a need (e.g., a missed medication, a concerning trend in vital signs) and *initiate* the appropriate action or recommendation.
# *   **Execute multi-step plans:** Go beyond simple reminders. It can understand a treatment plan, break it down into actionable steps, track progress, and even self-correct or flag issues for human intervention when necessary.
# *   **Operate continuously and adaptively:** It's always on, learning, and adjusting based on new data and user interactions, providing a level of ongoing, personalized support that is currently impossible to scale.
#
# **In essence, the industry is asking patients to be highly capable, multi-skilled, and eternally vigilant health managers. The current tools fail to adequately support this burden. Agentic AI offers a way to *offload* this burden and empower individuals by becoming their dedicated, intelligent, and proactive health orchestrator.** This is the true opportunity.
